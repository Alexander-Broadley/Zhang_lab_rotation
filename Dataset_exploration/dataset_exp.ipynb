# %%
# plots to check distribution of TF dataset - should already be TPM normalised and log10 transformed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#change this to folder in which 'Full data files' folder is in
DATA_ROOT = '/Users/alexanderbroadley/Documents/PhD/Zhang Lab/Zhang_Lab_Code/MML_model/data'

#load TF dataset
gene_expressions = pd.read_csv((f"{DATA_ROOT}/Full data files/Geneexpression (full).tsv"), sep='\t', header=0)
TF_expressions = pd.read_csv((f"{DATA_ROOT}/Full data files/TF(full).tsv"), sep='\t', header=0)

# %%
gene_expressions
# Out:
#            A1BG       A2M     A2ML1   A3GALT2    A4GALT      AAAS      AACS  \
# 0      1.103037  2.453714  0.080932  0.149036  1.638797  1.510672  0.576105
# 1      0.315785  2.406065  0.298752  0.000000  0.544888  0.501931  0.587212
# 2      0.630826  2.498732  0.148162  0.021514  0.634572  1.738609  0.970243
# 3      0.777204  2.493352  0.209044  0.027975  0.705359  1.769358  1.009512
# 4      0.736857  2.478016  0.134237  0.051799  0.746096  1.769308  1.004919
# ...         ...       ...       ...       ...       ...       ...       ...
# 15930  0.082311  0.134569  0.024612  0.000000  1.561996  1.781711  1.262138
# 15931  0.071488  0.170652  0.000000  0.069988  1.526367  1.756801  1.248976
# 15932  0.019623  0.166750  0.011075  0.133972  1.553726  1.761157  1.241091
# 15933  0.077525  0.137069  0.045015  0.000000  1.698391  1.608943  1.126351
# 15934  0.024247  0.098437  0.013716  0.000000  1.809723  1.658431  1.193593
#
# ...

# %%
original_GE = np.power(10, gene_expressions) - 1

# %%
original_TF = np.power(10, TF_expressions) - 1

# %%
original_GE.to_csv(f'{DATA_ROOT}/Genexpression_TPM.tsv', sep = '\t', index = False)
original_TF.to_csv(f'{DATA_ROOT}/TF_TPM.tsv', sep = '\t', index=False)

# %%
working_GE = pd.read_csv((f"{DATA_ROOT}/Full data files/Genexpression_TPM.tsv"), sep='\t', header=0, index_col=0)
working_TE = pd.read_csv((f"{DATA_ROOT}/Full data files/TF_TPM.tsv"), sep='\t', header=0, index_col=0)

# %%
working_GE
# Out:
#             A1BG         A2M     A2ML1   A3GALT2     A4GALT       AAAS  \
# 0      11.677592  283.258604  0.204846  0.409406  42.530798  31.409461
# 1       1.069119  253.721141  0.989539  0.000000   2.506613   2.176369
# 2       3.273916  314.305639  0.406571  0.050786   3.310941  53.778415
# 3       4.986921  310.423985  0.618243  0.066534   4.074100  57.797364
# 4       4.455780  299.618585  0.362186  0.126677   4.573094  57.790637
# ...          ...         ...       ...       ...        ...        ...
# 15930   0.208678    0.363229  0.058308  0.000000  35.475057  59.493837
# 15931   0.178930    0.481332  0.000000  0.174864  32.602144  56.121721
# 15932   0.046220    0.468081  0.025829  0.361356  34.787035  56.697436
# 15933   0.195433    0.371101  0.109214  0.000000  48.933407  39.639042
# 15934   0.057419    0.254404  0.032087  0.000000  63.524291  44.543931
#
#             AACS      AADAT      AAGAB      AAK1  ...       ZW10     ZWILCH  \
# ...
