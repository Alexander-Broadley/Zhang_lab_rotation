# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
DATA_ROOT = '../MML_model_building/data'

# %%
cirrhosis_exp = pd.read_csv(f"{DATA_ROOT}/Bulk06_expr.txt", sep ="\t", index_col = 0)

# %%
np.asarray(cirrhosis_exp).flatten()
# Out:
# array([38.83537772, 33.25704623, 38.78124701, ...,  2.478774  ,
#         2.29255   ,  1.1634    ], shape=(4019730,))

# %%
np.asarray(cirrhosis_exp).flatten().max()
# Out:
# np.float64(92762.49)

# %%
plt.hist(np.asarray(cirrhosis_exp).flatten())
# Out:
# (array([4.019474e+06, 1.670000e+02, 1.200000e+01, 3.000000e+00,
#         3.000000e+00, 9.000000e+00, 1.700000e+01, 2.400000e+01,
#         1.700000e+01, 4.000000e+00]),
#  array([    0.   ,  9276.249, 18552.498, 27828.747, 37104.996, 46381.245,
#         55657.494, 64933.743, 74209.992, 83486.241, 92762.49 ]),
#  <BarContainer object of 10 artists>)

# %%
cirrhosis_exp['SRR9036307']
# Out:
# gene
# TSPAN6        38.835378
# TNMD           0.107703
# DPM1          30.791871
# SCYL3          6.314987
# C1orf112       2.983507
#                 ...
# AL589743.7     0.000000
# AL355312.5     0.079882
# AC120036.5     0.000000
# AC018931.1     0.000000
# AL731559.1     1.626223
# Name: SRR9036307, Length: 51535, dtype: float64
