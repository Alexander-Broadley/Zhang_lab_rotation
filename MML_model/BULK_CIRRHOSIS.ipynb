# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import torch
#       4 from torch import nn
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
#      66     NA,
#      67     isna,
#      68     isnull,
#      69     notna,
#      70     notnull,
#      71     # indexes
#      72     Index,
#      73     CategoricalIndex,
#      74     RangeIndex,
#      75     MultiIndex,
#      76     IntervalIndex,
#      77     TimedeltaIndex,
#      78     DatetimeIndex,
#      79     PeriodIndex,
#      80     IndexSlice,
#      81     # tseries
#      82     NaT,
#      83     Period,
#      84     period_range,
#      85     Timedelta,
#      86     timedelta_range,
#      87     Timestamp,
#      88     date_range,
#      89     bdate_range,
#      90     Interval,
#      91     interval_range,
#      92     DateOffset,
#      93     # conversion
#      94     to_numeric,
#      95     to_datetime,
#      96     to_timedelta,
#      97     # misc
#      98     Flags,
#      99     Grouper,
#     100     factorize,
#     101     unique,
#     102     NamedAgg,
#     103     array,
#     104     Categorical,
#     105     set_eng_float_format,
#     106     Series,
#     107     DataFrame,
#     108 )
#     109 from pandas.core.col import col
#     111 from pandas.core.dtypes.dtypes import SparseDtype
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/api.py:46
#      44 from pandas.core.construction import array  # noqa: ICN001
#      45 from pandas.core.flags import Flags
# ---> 46 from pandas.core.groupby import (
#      47     Grouper,
#      48     NamedAgg,
#      49 )
#      50 from pandas.core.indexes.api import (
#      51     CategoricalIndex,
#      52     DatetimeIndex,
#    (...)     58     TimedeltaIndex,
#      59 )
#      60 from pandas.core.indexes.datetimes import (
#      61     bdate_range,
#      62     date_range,
#      63 )
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/groupby/__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/groupby/generic.py:64
#      57 from pandas.core.apply import (
#      58     GroupByApply,
#      59     maybe_mangle_lambdas,
#      60     reconstruct_func,
#      61     validate_func_kwargs,
#      62 )
#      63 import pandas.core.common as com
# ---> 64 from pandas.core.frame import DataFrame
#      65 from pandas.core.groupby import base
#      66 from pandas.core.groupby.groupby import (
#      67     GroupBy,
#      68     GroupByPlot,
#      69 )
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/frame.py:154
#     148 from pandas.core.arrays.string_ import StringDtype
#     149 from pandas.core.construction import (
#     150     ensure_wrapped_if_datetimelike,
#     151     sanitize_array,
#     152     sanitize_masked_array,
#     153 )
# --> 154 from pandas.core.generic import NDFrame
#     155 from pandas.core.indexers import check_key_length
#     156 from pandas.core.indexes.api import (
#     157     DatetimeIndex,
#     158     Index,
#    (...)    162     ensure_index_from_sequences,
#     163 )
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/generic.py:145
#     136 from pandas.core.dtypes.inference import (
#     137     is_hashable,
#     138     is_nested_list_like,
#     139 )
#     140 from pandas.core.dtypes.missing import (
#     141     isna,
#     142     notna,
#     143 )
# --> 145 from pandas.core import (
#     146     algorithms as algos,
#     147     arraylike,
#     148     common,
#     149     indexing,
#     150     missing,
#     151     nanops,
#     152     sample,
#     153 )
#     154 from pandas.core.array_algos.replace import should_use_regex
#     155 from pandas.core.arrays import ExtensionArray
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/indexing.py:74
#      64 from pandas.core.construction import (
#      65     array as pd_array,
#      66     extract_array,
#      67 )
#      68 from pandas.core.indexers import (
#      69     check_array_indexer,
#      70     is_list_like_indexer,
#      71     is_scalar_indexer,
#      72     length_of_indexer,
#      73 )
# ---> 74 from pandas.core.indexes.api import (
#      75     Index,
#      76     MultiIndex,
#      77 )
#      79 if TYPE_CHECKING:
#      80     from collections.abc import (
#      81         Hashable,
#      82         Sequence,
#      83     )
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/pandas/core/indexes/api.py:19
#      16 from pandas.core.dtypes.cast import find_common_type
#      18 from pandas.core.algorithms import safe_sort
# ---> 19 from pandas.core.indexes.base import (
#      20     Index,
#      21     _new_Index,
#      22     ensure_index,
#      23     ensure_index_from_sequences,
#      24     get_unanimous_names,
#      25     maybe_sequence_to_range,
#      26 )
#      27 from pandas.core.indexes.category import CategoricalIndex
#      28 from pandas.core.indexes.datetimes import DatetimeIndex
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1128, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:757, in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
DATA_ROOT = '../MML_model_building/data'

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
cirrhosis_exp = pd.read_csv(f"/home/alexanderb/Zhang_lab/MML_model/data/Cirrhosis_bulk/Bulk06_expr.txt", sep ="\t", index_col = 0)

# %%
DATA_ROOT = '/home/alexanderb/LEMBAS-RNN-benchmark'
#load GE dataset
gene_expressions = pd.read_csv((f"{DATA_ROOT}/Full data files/Geneexpression (full).tsv"), sep='\t', header=0)
#load TF dataset
TF_expressions = pd.read_csv((f"{DATA_ROOT}/Full data files/TF(full).tsv"), sep='\t', header=0)
net = pd.read_csv(f"{DATA_ROOT}/Full data files/network(full).tsv", sep='\t')

# %%
target_gene_actual = cirrhosis_exp.T['RPL27']

# %%
list(gene_expressions.columns).index('SEPHS2')
# Out:
# 'SEPHS2'

# %%
def TF_subset(net, target_gene):
    #simpler version as per discussion w/ Cheng
    #returns all the TFs in the network that directly connect to the target gene
    return(list(net['TF'][net['Gene'] == target_gene]))

# %%
TFs_to_keep = TF_subset(net, 'RPL27')
model_TFs = list(gene_expressions[[tf for tf in TFs_to_keep if tf in list(gene_expressions.columns)]])
TF_expression_subset = cirrhosis_exp.T[[tf for tf in model_TFs if tf in list(TF_expression_subset.columns)]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 TFs_to_keep = TF_subset(net, 'RPL27')
#       2 model_TFs = list(gene_expressions[[tf for tf in TFs_to_keep if tf in list(gene_expressions.columns)]])
# ----> 3 TF_expression_subset = cirrhosis_exp.T[[tf for tf in model_TFs if tf in list(TF_expression_subset.columns)]]
#
# NameError: name 'TF_expression_subset' is not defined

# %%
model = torch.load('/home/alexanderb/Zhang_lab/MML_model/models/TPM_models/RPL27_TPM_model.pth', weights_only=False)

# %%
from customTFGE_dataset import CustomTFGE

dataset = CustomTFGE(device, TF_expressions=TF_expression_subset, gene_expressions=cirrhosis_exp.T, network = net, target_gene = 'RPL27')

# %%
len(list(TF_expression_subset.columns))
# Out:
# 86

# %%
val_dataloader = DataLoader(dataset, batch_size=78, shuffle=False)

# %%
from gene_MSE_all_samples import gene_MSE_all_samples

# %%
loss_fn = nn.MSELoss()

# %%
model
# Out:
# SimpleMMLModel(
#   (linear_in): Linear(in_features=89, out_features=89, bias=True)
#   (linear_out): Linear(in_features=89, out_features=1, bias=True)
# )

# %%
len(model_TFs)
# Out:
# 86

# %%
gene_MSE_all_samples(val_dataloader, model, loss_fn, "TEMP")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 gene_MSE_all_samples(val_dataloader, model, loss_fn, "TEMP")
#
# File ~/Zhang_lab/MML_model/gene_MSE_all_samples.py:13, in gene_MSE_all_samples(dataloader, model, loss_fn, target_gene, rev_log)
#       9 with torch.no_grad():
#      10     for batch, (X, y) in enumerate(dataloader):
#      11
#      12         #create a prediction - this will be 1 value for given sample and target gene
# ---> 13         pred = model(X)
#      15         #for log(TPM+1) model reverse the transforms so MSE is comparable with TPM models
#      16         if rev_log == True:
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Zhang_lab/MML_model/simpleMMLModel.py:21, in SimpleMMLModel.forward(self, x)
#      19 def forward(self, x):
#      20     #project an input for each TF to activation with a linear layer
# ---> 21     expressions = self.linear_in(x)
#      22     expressions = self.activation(expressions, self.leak)
#      23     expressions = self.linear_out(x)
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/MML_ML/lib/python3.12/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (78x86 and 89x89)
